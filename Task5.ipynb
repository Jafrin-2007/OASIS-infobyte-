# %% [markdown]
# <a href="https://colab.research.google.com/github/Jafrin-2007/OASIS-infobyte-/blob/main/Task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.metrics import accuracy_score,confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-07ffade1-34e0-4be9-a3dd-3dcc7589b6e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07ffade1-34e0-4be9-a3dd-3dcc7589b6e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config', 'Advertising.csv', 'sample_data']

# %%
df=pd.read_csv("Advertising.csv")
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
x=df.iloc[:,1:4]
x
# Out:
#      Radio  Newspaper  Sales
# 0     37.8       69.2   22.1
# 1     39.3       45.1   10.4
# 2     45.9       69.3   12.0
# 3     41.3       58.5   16.5
# 4     10.8       58.4   17.9
# ..     ...        ...    ...
# 195    3.7       13.8    7.6
# 196    4.9        8.1   14.0
# 197    9.3        6.4   14.8
# 198   42.0       66.2   25.5
# 199    8.6        8.7   18.4
#
# [200 rows x 3 columns]

# %%
print(df.shape)
print(df.columns)
# Out:
# (200, 4)
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
X = df.iloc[:, :-1]   # all columns except last
Y = df.iloc[:, 3]     # Sales

# %%
X = df[['TV', 'Radio', 'Newspaper']]
Y = df['Sales']

# %%
X = df.iloc[:, :-1]
Y = df.iloc[:, -1]

X.head(), Y.head()
# Out:
# (      TV  Radio  Newspaper
#  0  230.1   37.8       69.2
#  1   44.5   39.3       45.1
#  2   17.2   45.9       69.3
#  3  151.5   41.3       58.5
#  4  180.8   10.8       58.4,
#  0    22.1
#  1    10.4
#  2    12.0
#  3    16.5
#  4    17.9
#  Name: Sales, dtype: float64)

# %%
plt.scatter(df['TV'],Y)
plt.title('TV Advertisements')
# Out:
# Text(0.5, 1.0, 'TV Advertisements')

# %%
plt.scatter(df['Radio'],Y)
plt.title('Radio Advertisements')
# Out:
# Text(0.5, 1.0, 'Radio Advertisements')

# %%
plt.scatter(df['Newspaper'],Y)
plt.title('Newspaper')
# Out:
# Text(0.5, 1.0, 'Newspaper')

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
cols=x.columns
x=scaler.fit_transform(x)
x=pd.DataFrame(x)
x.columns=cols
x
# Out:
#         Radio  Newspaper     Sales
# 0    0.981522   1.778945  1.322319
# 1    1.082808   0.669579 -0.897515
# 2    1.528463   1.783549 -0.593948
# 3    1.217855   1.286405  0.259834
# 4   -0.841614   1.281802  0.525455
# ..        ...        ...       ...
# 195 -1.321031  -0.771217 -1.428757
# 196 -1.240003  -1.033598 -0.214489
# 197 -0.942899  -1.111852 -0.062706
# 198  1.265121   1.640850  1.967398
# 199 -0.990165  -1.005979  0.620320
#
# [200 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=50,test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()
clf.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=clf.predict(X_test)
Y_pred
# Out:
# array([15.75794962, 18.17134589,  9.74175385, 12.34070552, 11.49222056,
#        19.64918472, 18.19572692,  5.1475777 , 21.11005581, 12.34169105,
#        18.29522856, 15.21611404, 21.11190856, 16.00443677, 19.42002757,
#        16.47438605, 12.24530993, 18.93647551,  9.61680474, 13.80366393,
#        15.73410136, 10.87798506,  9.28907166, 17.14236178, 22.85737856,
#        13.02696134,  9.58663616,  9.9137987 , 16.94619282, 16.50020272,
#        14.90023831, 12.9741163 , 10.37282166, 17.8467049 ,  8.82365705,
#         9.70073573, 13.23484082, 22.01927373, 10.61838055, 11.55219769,
#         8.5068976 , 25.15027621,  9.77899208, 18.21750753, 18.10088951,
#        10.92872349, 14.83011207, 19.60301721, 10.65624475,  7.99560502])

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(Y_test,Y_pred)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 1.887402736772442

# %%
# !pip install statsmodels

# %%
import statsmodels.api as sm

# %%
X = df[['TV', 'Radio', 'Newspaper']]
Y = df['Sales']

# %%
X2 = sm.add_constant(X)

# %%
model = sm.OLS(Y, X2)
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.901
# Method:                 Least Squares   F-statistic:                     605.4
# Date:                Wed, 17 Dec 2025   Prob (F-statistic):           8.13e-99
# Time:                        06:24:08   Log-Likelihood:                -383.34
# No. Observations:                 200   AIC:                             774.7
# Df Residuals:                     196   BIC:                             787.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.6251      0.308     15.041      0.000       4.019       5.232
# ...
